# %%
# --- 5-Number-Summary ---
# df[<column>].describe()[['min', '25%', '50%', '75%', 'max']]

# --- Anzahl Grupppen ---
# df.groupby(<column>).size()

# --- Scatter Matrix ---
# plt.plotting.scatter_matrix(df)

# --- Boxplot grouped by column ---
# df.boxplot(by=<group>, column=<column>)

# --- Pearsons Korrelationskoeffizient r(X, Y) = \frac{cov(X, Y)}{\sqrt{var(X)} \cdot \sqrt{var(Y)}} ---
# df.corr()

# --- Spearmans Korrelationskoeffizient r_{SP}(X, Y) = r(rg(X), rg(Y)) ---
# df.corr("spearman")
